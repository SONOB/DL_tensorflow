# %%
import tensorflow as tf

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train, x_test = x_train.astype('float32'), x_test.astype('float32')

x_train, x_test = x_train.reshape([-1, 784]), x_test.reshape([-1, 784])

x_train, x_test = x_train /255., x_test / 255.

# %%
learning_rate_RMSProp = 0.02
learning_rate_GradientDescent = 0.5
num_epochs = 100
batch_size = 256
display_step = 1
input_size = 784
hidden1_size = 128
hidden2_size = 64

# %%
train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_data = train_data.shuffle(60000).batch(batch_size)

# %%
def random_normal_intializer_with_stddev_1():
  return tf.keras.initializers.RandomNormal(mean=0.0, stddev=1.0, seed=None)

# %%
class AutoEncoder(tf.keras.Model):
  def __init__(self):
    super(AutoEncoder, self).__init__()

    self.hidden_layer_1 = tf.keras.layers.Dense(hidden1_size,
                                                activation='sigmoid',
                                                kernel_initializer=random_normal_intializer_with_stddev_1(),
                                                bias_initializer=random_normal_intializer_with_stddev_1())

    self.hidden_layer_2 = tf.keras.layers.Dense(hidden2_size,
                                                activation='sigmoid',
                                                kernel_initializer=random_normal_intializer_with_stddev_1(),
                                                bias_initializer=random_normal_intializer_with_stddev_1())

    self.hidden_layer_3 = tf.keras.layers.Dense(hidden1_size,
                                                activation='sigmoid',
                                                kernel_initializer=random_normal_intializer_with_stddev_1(),
                                                bias_initializer=random_normal_intializer_with_stddev_1())

    self.output_layer = tf.keras.layers.Dense(input_size,
                                              activation='sigmoid',
                                              kernel_initializer=random_normal_intializer_with_stddev_1(),
                                              bias_initializer=random_normal_intializer_with_stddev_1())

  def call(self,x):
    H1_output = self.hidden_layer_1(x)
    H2_output = self.hidden_layer_2(H1_output)
    H3_output = self.hidden_layer_3(H2_output)
    X_reconstructed = self.output_layer(H3_output)

    return X_reconstructed, H2_output

# %%
class SoftmaxClassifier(tf.keras.Model):
  def __init__(self):
    super(SoftmaxClassifier, self).__init__()

    self.softmax_layer = tf.keras.layers.Dense(10,
                                              activation='softmax',
                                              kernel_initializer='zeros',
                                              bias_initializer='zeros')

  def call(self, x):
    y_pred = self.softmax_layer(x)

    return y_pred

# %%
@tf.function
def pretraining_mse_loss(y_pred, y_true):
  return tf.reduce_mean(tf.pow(y_true - y_pred, 2))

# %%
@tf.function
def finetuning_cross_entropy_loss(y_pred_softmax, y):
  return tf.reduce_mean(-tf.reduce_sum(y * tf.math.log(y_pred_softmax), axis=[1]))

# %%
pretraining_optimizer = tf.optimizers.RMSprop(learning_rate_RMSProp, epsilon=1e-10)

# %%
@tf.function
def pretraining_train_step(autoencoder_model, x):

  y_true = x
  with tf.GradientTape() as tape:
    y_pred, _ = autoencoder_model(x)
    pretraining_loss = pretraining_mse_loss(y_pred, y_true)
  gradients = tape.gradient(pretraining_loss, autoencoder_model.trainable_variables)
  pretraining_optimizer.apply_gradients(zip(gradients, autoencoder_model.trainable_variables))

# %%
finetuning_optimizer = tf.optimizers.SGD(learning_rate_GradientDescent)

# %%
@tf.function
def finetuning_train_step(autoencoder_model, softmax_classifier_model, x, y):
  with tf.GradientTape() as tape:
    y_pred, extracted_features = autoencoder_model(x)
    y_pred_softmax = softmax_classifier_model(extracted_features)
    finetuning_loss = finetuning_cross_entropy_loss(y_pred_softmax, y)
  autoencoder_encoding_variables = autoencoder_model.hidden_layer_1.trainable_variables + autoencoder_model.hidden_layer_2.trainable_variables
  gradients = tape.gradient(finetuning_loss, autoencoder_encoding_variables + softmax_classifier_model.trainable_variables)
  finetuning_optimizer.apply_gradients(zip(gradients, autoencoder_encoding_variables + softmax_classifier_model.trainable_variables))

# %%
@tf.function
def compute_accuracy(y_pred_softmax, y):
  correct_prediction = tf.equal(tf.argmax(y_pred_softmax,1), tf.argmax(y,1))
  accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

  return accuracy

# %%
AutoEncoder_model = AutoEncoder()
SoftmaxClassifier_model = SoftmaxClassifier()

# %%
for epoch in range(num_epochs):
  for batch_x, _ in train_data:
    _, pretraining_loss_print = pretraining_train_step(AutoEncoder_model, batch_x), pretraining_mse_loss(AutoEncoder_model(batch_x)[0], batch_x)
  if epoch % display_step == 0:
    print("반복(Epoch): %d, Pre-Training 손실 함수(pretraining_loss): %f" % ((epoch + 1), pretraining_loss_print))
print("Step 1 : MNIST 데이터 재구축을 위한 오토인코더 최적화 완료(Pre-Training)")
# Out:
# 반복(Epoch): 1, Pre-Training 손실 함수(pretraining_loss): 0.111857
# 반복(Epoch): 2, Pre-Training 손실 함수(pretraining_loss): 0.093876
# 반복(Epoch): 3, Pre-Training 손실 함수(pretraining_loss): 0.081634
# 반복(Epoch): 4, Pre-Training 손실 함수(pretraining_loss): 0.077810
# 반복(Epoch): 5, Pre-Training 손실 함수(pretraining_loss): 0.067766
# 반복(Epoch): 6, Pre-Training 손실 함수(pretraining_loss): 0.063725
# 반복(Epoch): 7, Pre-Training 손실 함수(pretraining_loss): 0.063137
# 반복(Epoch): 8, Pre-Training 손실 함수(pretraining_loss): 0.058478
# 반복(Epoch): 9, Pre-Training 손실 함수(pretraining_loss): 0.055381
# 반복(Epoch): 10, Pre-Training 손실 함수(pretraining_loss): 0.053382
# 반복(Epoch): 11, Pre-Training 손실 함수(pretraining_loss): 0.052111
# 반복(Epoch): 12, Pre-Training 손실 함수(pretraining_loss): 0.051626
# 반복(Epoch): 13, Pre-Training 손실 함수(pretraining_loss): 0.047675
# 반복(Epoch): 14, Pre-Training 손실 함수(pretraining_loss): 0.047547
# 반복(Epoch): 15, Pre-Training 손실 함수(pretraining_loss): 0.043246
# 반복(Epoch): 16, Pre-Training 손실 함수(pretraining_loss): 0.045480
# 반복(Epoch): 17, Pre-Training 손실 함수(pretraining_loss): 0.043572
# 반복(Epoch): 18, Pre-Training 손실 함수(pretraining_loss): 0.045130
# 반복(Epoch): 19, Pre-Training 손실 함수(pretraining_loss): 0.041026
# 반복(Epoch): 20, Pre-Training 손실 함수(pretraining_loss): 0.038313
# 반복(Epoch): 21, Pre-Training 손실 함수(pretraining_loss): 0.040924
# 반복(Epoch): 22, Pre-Training 손실 함수(pretraining_loss): 0.043201
# 반복(Epoch): 23, Pre-Training 손실 함수(pretraining_loss): 0.039897
# 반복(Epoch): 24, Pre-Training 손실 함수(pretraining_loss): 0.042594
# 반복(Epoch): 25, Pre-Training 손실 함수(pretraining_loss): 0.038276
# 반복(Epoch): 26, Pre-Training 손실 함수(pretraining_loss): 0.038674
# 반복(Epoch): 27, Pre-Training 손실 함수(pretraining_loss): 0.038734
# 반복(Epoch): 28, Pre-Training 손실 함수(pretraining_loss): 0.036896
# 반복(Epoch): 29, Pre-Training 손실 함수(pretraining_loss): 0.038990
# 반복(Epoch): 30, Pre-Training 손실 함수(pretraining_loss): 0.037788
# 반복(Epoch): 31, Pre-Training 손실 함수(pretraining_loss): 0.036415
# 반복(Epoch): 32, Pre-Training 손실 함수(pretraining_loss): 0.037969
# 반복(Epoch): 33, Pre-Training 손실 함수(pretraining_loss): 0.035467
# 반복(Epoch): 34, Pre-Training 손실 함수(pretraining_loss): 0.032197
# 반복(Epoch): 35, Pre-Training 손실 함수(pretraining_loss): 0.033797
# 반복(Epoch): 36, Pre-Training 손실 함수(pretraining_loss): 0.031708
# 반복(Epoch): 37, Pre-Training 손실 함수(pretraining_loss): 0.029869
# 반복(Epoch): 38, Pre-Training 손실 함수(pretraining_loss): 0.031318
# 반복(Epoch): 39, Pre-Training 손실 함수(pretraining_loss): 0.030263
# 반복(Epoch): 40, Pre-Training 손실 함수(pretraining_loss): 0.031493
# 반복(Epoch): 41, Pre-Training 손실 함수(pretraining_loss): 0.027389
# 반복(Epoch): 42, Pre-Training 손실 함수(pretraining_loss): 0.029724
# 반복(Epoch): 43, Pre-Training 손실 함수(pretraining_loss): 0.029781
# 반복(Epoch): 44, Pre-Training 손실 함수(pretraining_loss): 0.029944
# 반복(Epoch): 45, Pre-Training 손실 함수(pretraining_loss): 0.028609
# 반복(Epoch): 46, Pre-Training 손실 함수(pretraining_loss): 0.026960
# 반복(Epoch): 47, Pre-Training 손실 함수(pretraining_loss): 0.028665
# 반복(Epoch): 48, Pre-Training 손실 함수(pretraining_loss): 0.024376
# 반복(Epoch): 49, Pre-Training 손실 함수(pretraining_loss): 0.027003
# 반복(Epoch): 50, Pre-Training 손실 함수(pretraining_loss): 0.023986
# 반복(Epoch): 51, Pre-Training 손실 함수(pretraining_loss): 0.025996
# 반복(Epoch): 52, Pre-Training 손실 함수(pretraining_loss): 0.025021
# 반복(Epoch): 53, Pre-Training 손실 함수(pretraining_loss): 0.025231
# 반복(Epoch): 54, Pre-Training 손실 함수(pretraining_loss): 0.022158
# 반복(Epoch): 55, Pre-Training 손실 함수(pretraining_loss): 0.021843
# 반복(Epoch): 56, Pre-Training 손실 함수(pretraining_loss): 0.021343
# 반복(Epoch): 57, Pre-Training 손실 함수(pretraining_loss): 0.022173
# 반복(Epoch): 58, Pre-Training 손실 함수(pretraining_loss): 0.022587
# 반복(Epoch): 59, Pre-Training 손실 함수(pretraining_loss): 0.022098
# 반복(Epoch): 60, Pre-Training 손실 함수(pretraining_loss): 0.019986
# 반복(Epoch): 61, Pre-Training 손실 함수(pretraining_loss): 0.019011
# 반복(Epoch): 62, Pre-Training 손실 함수(pretraining_loss): 0.022855
# 반복(Epoch): 63, Pre-Training 손실 함수(pretraining_loss): 0.021378
# 반복(Epoch): 64, Pre-Training 손실 함수(pretraining_loss): 0.019669
# 반복(Epoch): 65, Pre-Training 손실 함수(pretraining_loss): 0.024288
# 반복(Epoch): 66, Pre-Training 손실 함수(pretraining_loss): 0.018375
# 반복(Epoch): 67, Pre-Training 손실 함수(pretraining_loss): 0.020119
# 반복(Epoch): 68, Pre-Training 손실 함수(pretraining_loss): 0.017349
# 반복(Epoch): 69, Pre-Training 손실 함수(pretraining_loss): 0.018902
# 반복(Epoch): 70, Pre-Training 손실 함수(pretraining_loss): 0.021696
# 반복(Epoch): 71, Pre-Training 손실 함수(pretraining_loss): 0.020060
# 반복(Epoch): 72, Pre-Training 손실 함수(pretraining_loss): 0.018534
# 반복(Epoch): 73, Pre-Training 손실 함수(pretraining_loss): 0.015800
# 반복(Epoch): 74, Pre-Training 손실 함수(pretraining_loss): 0.019306
# 반복(Epoch): 75, Pre-Training 손실 함수(pretraining_loss): 0.015682
# 반복(Epoch): 76, Pre-Training 손실 함수(pretraining_loss): 0.020112
# 반복(Epoch): 77, Pre-Training 손실 함수(pretraining_loss): 0.017273
# 반복(Epoch): 78, Pre-Training 손실 함수(pretraining_loss): 0.019685
# 반복(Epoch): 79, Pre-Training 손실 함수(pretraining_loss): 0.018257
# 반복(Epoch): 80, Pre-Training 손실 함수(pretraining_loss): 0.018819
# 반복(Epoch): 81, Pre-Training 손실 함수(pretraining_loss): 0.020587
# 반복(Epoch): 82, Pre-Training 손실 함수(pretraining_loss): 0.019188
# 반복(Epoch): 83, Pre-Training 손실 함수(pretraining_loss): 0.015596
# 반복(Epoch): 84, Pre-Training 손실 함수(pretraining_loss): 0.018694
# 반복(Epoch): 85, Pre-Training 손실 함수(pretraining_loss): 0.017412
# 반복(Epoch): 86, Pre-Training 손실 함수(pretraining_loss): 0.018091
# 반복(Epoch): 87, Pre-Training 손실 함수(pretraining_loss): 0.018222
# 반복(Epoch): 88, Pre-Training 손실 함수(pretraining_loss): 0.017785
# 반복(Epoch): 89, Pre-Training 손실 함수(pretraining_loss): 0.017249
# 반복(Epoch): 90, Pre-Training 손실 함수(pretraining_loss): 0.019225
# 반복(Epoch): 91, Pre-Training 손실 함수(pretraining_loss): 0.015729
# 반복(Epoch): 92, Pre-Training 손실 함수(pretraining_loss): 0.016219
# 반복(Epoch): 93, Pre-Training 손실 함수(pretraining_loss): 0.017263
# 반복(Epoch): 94, Pre-Training 손실 함수(pretraining_loss): 0.014727
# 반복(Epoch): 95, Pre-Training 손실 함수(pretraining_loss): 0.014759
# 반복(Epoch): 96, Pre-Training 손실 함수(pretraining_loss): 0.014958
# 반복(Epoch): 97, Pre-Training 손실 함수(pretraining_loss): 0.016724
# 반복(Epoch): 98, Pre-Training 손실 함수(pretraining_loss): 0.017966
# 반복(Epoch): 99, Pre-Training 손실 함수(pretraining_loss): 0.013698
# 반복(Epoch): 100, Pre-Training 손실 함수(pretraining_loss): 0.013563
# Step 1 : MNIST 데이터 재구축을 위한 오토인코더 최적화 완료(Pre-Training)

# %%
for epoch in range(num_epochs + 100):

  for batch_x, batch_y in train_data:
    batch_y = tf.one_hot(batch_y, depth=10)
    _, finetuning_loss_print = finetuning_train_step(AutoEncoder_model, SoftmaxClassifier_model, batch_x, batch_y), finetuning_cross_entropy_loss(SoftmaxClassifier_model(AutoEncoder_model(batch_x)[1]), batch_y)

  if epoch % display_step == 0:
    print("반복(Epoch): %d, Fine-tuning 손실 함수(finetuning_loss): %f" % ((epoch + 1), finetuning_loss_print))
print("Step 2 : MNIST 데이터 분류를 위한 오토인코더+Softmax 분류기 최적화 완료(Fine-Tuning)")
# Out:
# 반복(Epoch): 1, Fine-tuning 손실 함수(finetuning_loss): 0.522633
# 반복(Epoch): 2, Fine-tuning 손실 함수(finetuning_loss): 0.291853
# 반복(Epoch): 3, Fine-tuning 손실 함수(finetuning_loss): 0.250015
# 반복(Epoch): 4, Fine-tuning 손실 함수(finetuning_loss): 0.160413
# 반복(Epoch): 5, Fine-tuning 손실 함수(finetuning_loss): 0.164048
# 반복(Epoch): 6, Fine-tuning 손실 함수(finetuning_loss): 0.404381
# 반복(Epoch): 7, Fine-tuning 손실 함수(finetuning_loss): 0.148457
# 반복(Epoch): 8, Fine-tuning 손실 함수(finetuning_loss): 0.158081
# 반복(Epoch): 9, Fine-tuning 손실 함수(finetuning_loss): 0.212685
# 반복(Epoch): 10, Fine-tuning 손실 함수(finetuning_loss): 0.287406
# 반복(Epoch): 11, Fine-tuning 손실 함수(finetuning_loss): 0.155827
# 반복(Epoch): 12, Fine-tuning 손실 함수(finetuning_loss): 0.149580
# 반복(Epoch): 13, Fine-tuning 손실 함수(finetuning_loss): 0.193131
# 반복(Epoch): 14, Fine-tuning 손실 함수(finetuning_loss): 0.109462
# 반복(Epoch): 15, Fine-tuning 손실 함수(finetuning_loss): 0.097395
# 반복(Epoch): 16, Fine-tuning 손실 함수(finetuning_loss): 0.099171
# 반복(Epoch): 17, Fine-tuning 손실 함수(finetuning_loss): 0.135146
# 반복(Epoch): 18, Fine-tuning 손실 함수(finetuning_loss): 0.178206
# 반복(Epoch): 19, Fine-tuning 손실 함수(finetuning_loss): 0.165219
# 반복(Epoch): 20, Fine-tuning 손실 함수(finetuning_loss): 0.166333
# 반복(Epoch): 21, Fine-tuning 손실 함수(finetuning_loss): 0.054539
# 반복(Epoch): 22, Fine-tuning 손실 함수(finetuning_loss): 0.164805
# 반복(Epoch): 23, Fine-tuning 손실 함수(finetuning_loss): 0.060412
# 반복(Epoch): 24, Fine-tuning 손실 함수(finetuning_loss): 0.110702
# 반복(Epoch): 25, Fine-tuning 손실 함수(finetuning_loss): 0.126357
# 반복(Epoch): 26, Fine-tuning 손실 함수(finetuning_loss): 0.066698
# 반복(Epoch): 27, Fine-tuning 손실 함수(finetuning_loss): 0.037739
# 반복(Epoch): 28, Fine-tuning 손실 함수(finetuning_loss): 0.049956
# 반복(Epoch): 29, Fine-tuning 손실 함수(finetuning_loss): 0.049431
# 반복(Epoch): 30, Fine-tuning 손실 함수(finetuning_loss): 0.101973
# 반복(Epoch): 31, Fine-tuning 손실 함수(finetuning_loss): 0.137869
# 반복(Epoch): 32, Fine-tuning 손실 함수(finetuning_loss): 0.049972
# 반복(Epoch): 33, Fine-tuning 손실 함수(finetuning_loss): 0.024256
# 반복(Epoch): 34, Fine-tuning 손실 함수(finetuning_loss): 0.140645
# 반복(Epoch): 35, Fine-tuning 손실 함수(finetuning_loss): 0.053354
# 반복(Epoch): 36, Fine-tuning 손실 함수(finetuning_loss): 0.046279
# 반복(Epoch): 37, Fine-tuning 손실 함수(finetuning_loss): 0.067563
# 반복(Epoch): 38, Fine-tuning 손실 함수(finetuning_loss): 0.028046
# 반복(Epoch): 39, Fine-tuning 손실 함수(finetuning_loss): 0.046051
# 반복(Epoch): 40, Fine-tuning 손실 함수(finetuning_loss): 0.073340
# 반복(Epoch): 41, Fine-tuning 손실 함수(finetuning_loss): 0.073402
# 반복(Epoch): 42, Fine-tuning 손실 함수(finetuning_loss): 0.052091
# 반복(Epoch): 43, Fine-tuning 손실 함수(finetuning_loss): 0.061951
# 반복(Epoch): 44, Fine-tuning 손실 함수(finetuning_loss): 0.081293
# 반복(Epoch): 45, Fine-tuning 손실 함수(finetuning_loss): 0.105683
# 반복(Epoch): 46, Fine-tuning 손실 함수(finetuning_loss): 0.057324
# 반복(Epoch): 47, Fine-tuning 손실 함수(finetuning_loss): 0.040182
# 반복(Epoch): 48, Fine-tuning 손실 함수(finetuning_loss): 0.051488
# 반복(Epoch): 49, Fine-tuning 손실 함수(finetuning_loss): 0.071243
# 반복(Epoch): 50, Fine-tuning 손실 함수(finetuning_loss): 0.037415
# 반복(Epoch): 51, Fine-tuning 손실 함수(finetuning_loss): 0.038000
# 반복(Epoch): 52, Fine-tuning 손실 함수(finetuning_loss): 0.075122
# 반복(Epoch): 53, Fine-tuning 손실 함수(finetuning_loss): 0.069080
# 반복(Epoch): 54, Fine-tuning 손실 함수(finetuning_loss): 0.076778
# 반복(Epoch): 55, Fine-tuning 손실 함수(finetuning_loss): 0.023965
# 반복(Epoch): 56, Fine-tuning 손실 함수(finetuning_loss): 0.027430
# 반복(Epoch): 57, Fine-tuning 손실 함수(finetuning_loss): 0.055462
# 반복(Epoch): 58, Fine-tuning 손실 함수(finetuning_loss): 0.028754
# 반복(Epoch): 59, Fine-tuning 손실 함수(finetuning_loss): 0.042305
# 반복(Epoch): 60, Fine-tuning 손실 함수(finetuning_loss): 0.008490
# 반복(Epoch): 61, Fine-tuning 손실 함수(finetuning_loss): 0.047800
# 반복(Epoch): 62, Fine-tuning 손실 함수(finetuning_loss): 0.065228
# 반복(Epoch): 63, Fine-tuning 손실 함수(finetuning_loss): 0.034202
# 반복(Epoch): 64, Fine-tuning 손실 함수(finetuning_loss): 0.050915
# 반복(Epoch): 65, Fine-tuning 손실 함수(finetuning_loss): 0.030907
# 반복(Epoch): 66, Fine-tuning 손실 함수(finetuning_loss): 0.034761
# 반복(Epoch): 67, Fine-tuning 손실 함수(finetuning_loss): 0.031072
# 반복(Epoch): 68, Fine-tuning 손실 함수(finetuning_loss): 0.018807
# 반복(Epoch): 69, Fine-tuning 손실 함수(finetuning_loss): 0.048943
# 반복(Epoch): 70, Fine-tuning 손실 함수(finetuning_loss): 0.019464
# 반복(Epoch): 71, Fine-tuning 손실 함수(finetuning_loss): 0.073128
# 반복(Epoch): 72, Fine-tuning 손실 함수(finetuning_loss): 0.035446
# 반복(Epoch): 73, Fine-tuning 손실 함수(finetuning_loss): 0.017135
# 반복(Epoch): 74, Fine-tuning 손실 함수(finetuning_loss): 0.043044
# 반복(Epoch): 75, Fine-tuning 손실 함수(finetuning_loss): 0.021410
# 반복(Epoch): 76, Fine-tuning 손실 함수(finetuning_loss): 0.120510
# 반복(Epoch): 77, Fine-tuning 손실 함수(finetuning_loss): 0.123289
# 반복(Epoch): 78, Fine-tuning 손실 함수(finetuning_loss): 0.036084
# 반복(Epoch): 79, Fine-tuning 손실 함수(finetuning_loss): 0.037931
# 반복(Epoch): 80, Fine-tuning 손실 함수(finetuning_loss): 0.027197
# 반복(Epoch): 81, Fine-tuning 손실 함수(finetuning_loss): 0.041218
# 반복(Epoch): 82, Fine-tuning 손실 함수(finetuning_loss): 0.026477
# 반복(Epoch): 83, Fine-tuning 손실 함수(finetuning_loss): 0.042949
# 반복(Epoch): 84, Fine-tuning 손실 함수(finetuning_loss): 0.064228
# 반복(Epoch): 85, Fine-tuning 손실 함수(finetuning_loss): 0.066156
# 반복(Epoch): 86, Fine-tuning 손실 함수(finetuning_loss): 0.032008
# 반복(Epoch): 87, Fine-tuning 손실 함수(finetuning_loss): 0.021401
# 반복(Epoch): 88, Fine-tuning 손실 함수(finetuning_loss): 0.027138
# 반복(Epoch): 89, Fine-tuning 손실 함수(finetuning_loss): 0.015578
# 반복(Epoch): 90, Fine-tuning 손실 함수(finetuning_loss): 0.037005
# 반복(Epoch): 91, Fine-tuning 손실 함수(finetuning_loss): 0.018558
# 반복(Epoch): 92, Fine-tuning 손실 함수(finetuning_loss): 0.027409
# 반복(Epoch): 93, Fine-tuning 손실 함수(finetuning_loss): 0.034158
# 반복(Epoch): 94, Fine-tuning 손실 함수(finetuning_loss): 0.039856
# 반복(Epoch): 95, Fine-tuning 손실 함수(finetuning_loss): 0.035825
# 반복(Epoch): 96, Fine-tuning 손실 함수(finetuning_loss): 0.048634
# 반복(Epoch): 97, Fine-tuning 손실 함수(finetuning_loss): 0.010756
# 반복(Epoch): 98, Fine-tuning 손실 함수(finetuning_loss): 0.037024
# 반복(Epoch): 99, Fine-tuning 손실 함수(finetuning_loss): 0.010624
# 반복(Epoch): 100, Fine-tuning 손실 함수(finetuning_loss): 0.060763
# 반복(Epoch): 101, Fine-tuning 손실 함수(finetuning_loss): 0.014248
# 반복(Epoch): 102, Fine-tuning 손실 함수(finetuning_loss): 0.011734
# 반복(Epoch): 103, Fine-tuning 손실 함수(finetuning_loss): 0.032150
# 반복(Epoch): 104, Fine-tuning 손실 함수(finetuning_loss): 0.016829
# 반복(Epoch): 105, Fine-tuning 손실 함수(finetuning_loss): 0.010311
# 반복(Epoch): 106, Fine-tuning 손실 함수(finetuning_loss): 0.028444
# 반복(Epoch): 107, Fine-tuning 손실 함수(finetuning_loss): 0.018305
# 반복(Epoch): 108, Fine-tuning 손실 함수(finetuning_loss): 0.074060
# 반복(Epoch): 109, Fine-tuning 손실 함수(finetuning_loss): 0.016976
# 반복(Epoch): 110, Fine-tuning 손실 함수(finetuning_loss): 0.012284
# 반복(Epoch): 111, Fine-tuning 손실 함수(finetuning_loss): 0.040446
# 반복(Epoch): 112, Fine-tuning 손실 함수(finetuning_loss): 0.062006
# 반복(Epoch): 113, Fine-tuning 손실 함수(finetuning_loss): 0.019462
# 반복(Epoch): 114, Fine-tuning 손실 함수(finetuning_loss): 0.039023
# 반복(Epoch): 115, Fine-tuning 손실 함수(finetuning_loss): 0.014182
# 반복(Epoch): 116, Fine-tuning 손실 함수(finetuning_loss): 0.058838
# 반복(Epoch): 117, Fine-tuning 손실 함수(finetuning_loss): 0.013369
# 반복(Epoch): 118, Fine-tuning 손실 함수(finetuning_loss): 0.024207
# 반복(Epoch): 119, Fine-tuning 손실 함수(finetuning_loss): 0.012002
# 반복(Epoch): 120, Fine-tuning 손실 함수(finetuning_loss): 0.013131
# 반복(Epoch): 121, Fine-tuning 손실 함수(finetuning_loss): 0.022949
# 반복(Epoch): 122, Fine-tuning 손실 함수(finetuning_loss): 0.149565
# 반복(Epoch): 123, Fine-tuning 손실 함수(finetuning_loss): 0.014512
# 반복(Epoch): 124, Fine-tuning 손실 함수(finetuning_loss): 0.019795
# 반복(Epoch): 125, Fine-tuning 손실 함수(finetuning_loss): 0.014928
# 반복(Epoch): 126, Fine-tuning 손실 함수(finetuning_loss): 0.016519
# 반복(Epoch): 127, Fine-tuning 손실 함수(finetuning_loss): 0.017655
# 반복(Epoch): 128, Fine-tuning 손실 함수(finetuning_loss): 0.015747
# 반복(Epoch): 129, Fine-tuning 손실 함수(finetuning_loss): 0.016397
# 반복(Epoch): 130, Fine-tuning 손실 함수(finetuning_loss): 0.011978
# 반복(Epoch): 131, Fine-tuning 손실 함수(finetuning_loss): 0.003810
# 반복(Epoch): 132, Fine-tuning 손실 함수(finetuning_loss): 0.042377
# 반복(Epoch): 133, Fine-tuning 손실 함수(finetuning_loss): 0.009402
# 반복(Epoch): 134, Fine-tuning 손실 함수(finetuning_loss): 0.030543
# 반복(Epoch): 135, Fine-tuning 손실 함수(finetuning_loss): 0.029047
# 반복(Epoch): 136, Fine-tuning 손실 함수(finetuning_loss): 0.007720
# 반복(Epoch): 137, Fine-tuning 손실 함수(finetuning_loss): 0.012604
# 반복(Epoch): 138, Fine-tuning 손실 함수(finetuning_loss): 0.009508
# 반복(Epoch): 139, Fine-tuning 손실 함수(finetuning_loss): 0.017135
# 반복(Epoch): 140, Fine-tuning 손실 함수(finetuning_loss): 0.010712
# 반복(Epoch): 141, Fine-tuning 손실 함수(finetuning_loss): 0.006132
# 반복(Epoch): 142, Fine-tuning 손실 함수(finetuning_loss): 0.033058
# 반복(Epoch): 143, Fine-tuning 손실 함수(finetuning_loss): 0.009772
# 반복(Epoch): 144, Fine-tuning 손실 함수(finetuning_loss): 0.020209
# 반복(Epoch): 145, Fine-tuning 손실 함수(finetuning_loss): 0.010373
# 반복(Epoch): 146, Fine-tuning 손실 함수(finetuning_loss): 0.018991
# 반복(Epoch): 147, Fine-tuning 손실 함수(finetuning_loss): 0.012954
# 반복(Epoch): 148, Fine-tuning 손실 함수(finetuning_loss): 0.005558
# 반복(Epoch): 149, Fine-tuning 손실 함수(finetuning_loss): 0.012532
# 반복(Epoch): 150, Fine-tuning 손실 함수(finetuning_loss): 0.012962
# 반복(Epoch): 151, Fine-tuning 손실 함수(finetuning_loss): 0.023413
# 반복(Epoch): 152, Fine-tuning 손실 함수(finetuning_loss): 0.104609
# 반복(Epoch): 153, Fine-tuning 손실 함수(finetuning_loss): 0.029070
# 반복(Epoch): 154, Fine-tuning 손실 함수(finetuning_loss): 0.019962
# 반복(Epoch): 155, Fine-tuning 손실 함수(finetuning_loss): 0.016084
# 반복(Epoch): 156, Fine-tuning 손실 함수(finetuning_loss): 0.003761
# 반복(Epoch): 157, Fine-tuning 손실 함수(finetuning_loss): 0.016204
# 반복(Epoch): 158, Fine-tuning 손실 함수(finetuning_loss): 0.024446
# 반복(Epoch): 159, Fine-tuning 손실 함수(finetuning_loss): 0.025395
# 반복(Epoch): 160, Fine-tuning 손실 함수(finetuning_loss): 0.017134
# 반복(Epoch): 161, Fine-tuning 손실 함수(finetuning_loss): 0.009211
# 반복(Epoch): 162, Fine-tuning 손실 함수(finetuning_loss): 0.008849
# 반복(Epoch): 163, Fine-tuning 손실 함수(finetuning_loss): 0.006505
# 반복(Epoch): 164, Fine-tuning 손실 함수(finetuning_loss): 0.017280
# 반복(Epoch): 165, Fine-tuning 손실 함수(finetuning_loss): 0.013620
# 반복(Epoch): 166, Fine-tuning 손실 함수(finetuning_loss): 0.014227
# 반복(Epoch): 167, Fine-tuning 손실 함수(finetuning_loss): 0.014456
# 반복(Epoch): 168, Fine-tuning 손실 함수(finetuning_loss): 0.008712
# 반복(Epoch): 169, Fine-tuning 손실 함수(finetuning_loss): 0.004312
# 반복(Epoch): 170, Fine-tuning 손실 함수(finetuning_loss): 0.008061
# 반복(Epoch): 171, Fine-tuning 손실 함수(finetuning_loss): 0.055673
# 반복(Epoch): 172, Fine-tuning 손실 함수(finetuning_loss): 0.016005
# 반복(Epoch): 173, Fine-tuning 손실 함수(finetuning_loss): 0.008883
# 반복(Epoch): 174, Fine-tuning 손실 함수(finetuning_loss): 0.016438
# 반복(Epoch): 175, Fine-tuning 손실 함수(finetuning_loss): 0.008418
# 반복(Epoch): 176, Fine-tuning 손실 함수(finetuning_loss): 0.005583
# 반복(Epoch): 177, Fine-tuning 손실 함수(finetuning_loss): 0.008830
# 반복(Epoch): 178, Fine-tuning 손실 함수(finetuning_loss): 0.007466
# 반복(Epoch): 179, Fine-tuning 손실 함수(finetuning_loss): 0.009232
# 반복(Epoch): 180, Fine-tuning 손실 함수(finetuning_loss): 0.007009
# 반복(Epoch): 181, Fine-tuning 손실 함수(finetuning_loss): 0.008752
# 반복(Epoch): 182, Fine-tuning 손실 함수(finetuning_loss): 0.005734
# 반복(Epoch): 183, Fine-tuning 손실 함수(finetuning_loss): 0.012559
# 반복(Epoch): 184, Fine-tuning 손실 함수(finetuning_loss): 0.008124
# 반복(Epoch): 185, Fine-tuning 손실 함수(finetuning_loss): 0.014105
# 반복(Epoch): 186, Fine-tuning 손실 함수(finetuning_loss): 0.011428
# 반복(Epoch): 187, Fine-tuning 손실 함수(finetuning_loss): 0.009069
# 반복(Epoch): 188, Fine-tuning 손실 함수(finetuning_loss): 0.013941
# 반복(Epoch): 189, Fine-tuning 손실 함수(finetuning_loss): 0.003937
# 반복(Epoch): 190, Fine-tuning 손실 함수(finetuning_loss): 0.005073
# 반복(Epoch): 191, Fine-tuning 손실 함수(finetuning_loss): 0.002321
# 반복(Epoch): 192, Fine-tuning 손실 함수(finetuning_loss): 0.004432
# 반복(Epoch): 193, Fine-tuning 손실 함수(finetuning_loss): 0.005410
# 반복(Epoch): 194, Fine-tuning 손실 함수(finetuning_loss): 0.011826
# 반복(Epoch): 195, Fine-tuning 손실 함수(finetuning_loss): 0.014764
# 반복(Epoch): 196, Fine-tuning 손실 함수(finetuning_loss): 0.009887
# 반복(Epoch): 197, Fine-tuning 손실 함수(finetuning_loss): 0.007309
# 반복(Epoch): 198, Fine-tuning 손실 함수(finetuning_loss): 0.007482
# 반복(Epoch): 199, Fine-tuning 손실 함수(finetuning_loss): 0.010643
# 반복(Epoch): 200, Fine-tuning 손실 함수(finetuning_loss): 0.008166
# Step 2 : MNIST 데이터 분류를 위한 오토인코더+Softmax 분류기 최적화 완료(Fine-Tuning)

# %%
print("정확도(오토인코더+Softmax 분류기): %f" % compute_accuracy(SoftmaxClassifier_model(AutoEncoder_model(x_test)[1]), tf.one_hot(y_test, depth=10)))
# Out:
# 정확도(오토인코더+Softmax 분류기): 0.964800
