# %%
import tensorflow as tf

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

x_train, x_test = x_train.astype('float32'), x_test.astype('float32')

x_train, x_test = x_train/255., x_test/255.

y_train_one_hot = tf.squeeze(tf.one_hot(y_train, 10), axis=1)
y_test_one_hot = tf.squeeze(tf.one_hot(y_test, 10), axis=1)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 13s 0us/step

# %%
train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train_one_hot))
train_data = train_data.repeat().shuffle(50000).batch(128)
train_data_iter = iter(train_data)

# %%
test_data = tf.data.Dataset.from_tensor_slices((x_test, y_test_one_hot))
test_data = test_data.batch(1000)
test_data_iter = iter(test_data)

# %%
class CNN(tf.keras.Model):
  def __init__(self):
    super(CNN, self).__init__()

    self.conv_layer_1 = tf.keras.layers.Conv2D(filters=64, kernel_size=3, strides=1, padding='same', activation='relu')
    self.pool_layer_1 = tf.keras.layers.MaxPool2D(pool_size=(3, 3), strides=2)

    self.conv_layer_2 = tf.keras.layers.Conv2D(filters=64, kernel_size=3, strides=1, padding='same', activation='relu')
    self.pool_layer_2 = tf.keras.layers.MaxPool2D(pool_size=(3, 3), strides=2)

    self.conv_layer_3 = tf.keras.layers.Conv2D(filters=128, kernel_size=3, strides=1, padding='same', activation='relu')
    self.conv_layer_4 = tf.keras.layers.Conv2D(filters=128, kernel_size=3, strides=1, padding='same', activation='relu')
    self.conv_layer_5 = tf.keras.layers.Conv2D(filters=128, kernel_size=3, strides=1, padding='same', activation='relu')

    self.flatten_layer = tf.keras.layers.Flatten()
    self.fc_layer_1 = tf.keras.layers.Dense(384, activation='relu')
    self.dropout = tf.keras.layers.Dropout(0.2)

    self.output_layer = tf.keras.layers.Dense(10, activation=None)

  def call(self, x, is_training):

    h_conv1 = self.conv_layer_1(x)
    h_pool1 = self.pool_layer_1(h_conv1)
    h_conv2 = self.conv_layer_2(h_pool1)
    h_pool2 = self.pool_layer_2(h_conv2)
    h_conv3 = self.conv_layer_3(h_pool2)
    h_conv4 = self.conv_layer_4(h_conv3)
    h_conv5 = self.conv_layer_5(h_conv4)
    h_conv5_flat = self.flatten_layer(h_conv5)
    h_fc1 = self.fc_layer_1(h_conv5_flat)

    h_fc1_drop = self.dropout(h_fc1, training=is_training)
    logits = self.output_layer(h_fc1_drop)
    y_pred = tf.nn.softmax(logits)

    return y_pred, logits

# %%
@tf.function
def cross_entropy_loss(logits, y):
  return tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))

optimizer = tf.optimizers.RMSprop(1e-3)

# %%
@tf.function
def train_step(model, x, y, is_training):
  with tf.GradientTape() as tape:
    y_pred, logits = model(x, is_training)
    loss = cross_entropy_loss(logits, y)
  gradients = tape.gradient(loss, model.trainable_variables)
  optimizer.apply_gradients(zip(gradients, model.trainable_variables))

# %%
@tf.function
def compute_accuracy(y_pred, y):
  correct_prediction = tf.equal(tf.argmax(y_pred,1), tf.argmax(y,1))
  accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

  return accuracy

# %%
CNN_model = CNN()

# %%
for i in range(10000):
  batch_x, batch_y = next(train_data_iter)

  if i % 100 == 0:
    train_accuracy = compute_accuracy(CNN_model(batch_x, False)[0], batch_y)
    loss_print = cross_entropy_loss(CNN_model(batch_x, False)[1], batch_y)

    print("반복(Epoch): %d, 트레이닝 데이터 정확도: %f, 손실 함수(loss): %f" % (i, train_accuracy, loss_print))
  train_step(CNN_model, batch_x, batch_y, True)
# Out:
# 반복(Epoch): 0, 트레이닝 데이터 정확도: 0.148438, 손실 함수(loss): 2.304136
# 반복(Epoch): 100, 트레이닝 데이터 정확도: 0.203125, 손실 함수(loss): 2.070612
# 반복(Epoch): 200, 트레이닝 데이터 정확도: 0.250000, 손실 함수(loss): 2.080671
# 반복(Epoch): 300, 트레이닝 데이터 정확도: 0.312500, 손실 함수(loss): 1.887711
# 반복(Epoch): 400, 트레이닝 데이터 정확도: 0.531250, 손실 함수(loss): 1.429114
# 반복(Epoch): 500, 트레이닝 데이터 정확도: 0.390625, 손실 함수(loss): 1.548010
# 반복(Epoch): 600, 트레이닝 데이터 정확도: 0.507812, 손실 함수(loss): 1.243764
# 반복(Epoch): 700, 트레이닝 데이터 정확도: 0.429688, 손실 함수(loss): 1.393081
# 반복(Epoch): 800, 트레이닝 데이터 정확도: 0.414062, 손실 함수(loss): 1.642085
# 반복(Epoch): 900, 트레이닝 데이터 정확도: 0.617188, 손실 함수(loss): 1.083556
# 반복(Epoch): 1000, 트레이닝 데이터 정확도: 0.656250, 손실 함수(loss): 0.976610
# 반복(Epoch): 1100, 트레이닝 데이터 정확도: 0.671875, 손실 함수(loss): 1.010362
# 반복(Epoch): 1200, 트레이닝 데이터 정확도: 0.671875, 손실 함수(loss): 1.002083
# 반복(Epoch): 1300, 트레이닝 데이터 정확도: 0.664062, 손실 함수(loss): 0.828210
# 반복(Epoch): 1400, 트레이닝 데이터 정확도: 0.656250, 손실 함수(loss): 0.924710
# 반복(Epoch): 1500, 트레이닝 데이터 정확도: 0.710938, 손실 함수(loss): 0.845047
# 반복(Epoch): 1600, 트레이닝 데이터 정확도: 0.695312, 손실 함수(loss): 0.801554
# 반복(Epoch): 1700, 트레이닝 데이터 정확도: 0.656250, 손실 함수(loss): 1.106564
# 반복(Epoch): 1800, 트레이닝 데이터 정확도: 0.601562, 손실 함수(loss): 1.180270
# 반복(Epoch): 1900, 트레이닝 데이터 정확도: 0.710938, 손실 함수(loss): 0.845446
# 반복(Epoch): 2000, 트레이닝 데이터 정확도: 0.781250, 손실 함수(loss): 0.646272
# 반복(Epoch): 2100, 트레이닝 데이터 정확도: 0.765625, 손실 함수(loss): 0.673947
# 반복(Epoch): 2200, 트레이닝 데이터 정확도: 0.773438, 손실 함수(loss): 0.609594
# 반복(Epoch): 2300, 트레이닝 데이터 정확도: 0.718750, 손실 함수(loss): 0.837507
# 반복(Epoch): 2400, 트레이닝 데이터 정확도: 0.812500, 손실 함수(loss): 0.579264
# 반복(Epoch): 2500, 트레이닝 데이터 정확도: 0.812500, 손실 함수(loss): 0.610624
# 반복(Epoch): 2600, 트레이닝 데이터 정확도: 0.750000, 손실 함수(loss): 0.655233
# 반복(Epoch): 2700, 트레이닝 데이터 정확도: 0.757812, 손실 함수(loss): 0.543648
# 반복(Epoch): 2800, 트레이닝 데이터 정확도: 0.867188, 손실 함수(loss): 0.369102
# 반복(Epoch): 2900, 트레이닝 데이터 정확도: 0.796875, 손실 함수(loss): 0.524456
# 반복(Epoch): 3000, 트레이닝 데이터 정확도: 0.851562, 손실 함수(loss): 0.431958
# 반복(Epoch): 3100, 트레이닝 데이터 정확도: 0.843750, 손실 함수(loss): 0.417697
# 반복(Epoch): 3200, 트레이닝 데이터 정확도: 0.820312, 손실 함수(loss): 0.570625
# 반복(Epoch): 3300, 트레이닝 데이터 정확도: 0.867188, 손실 함수(loss): 0.471635
# 반복(Epoch): 3400, 트레이닝 데이터 정확도: 0.867188, 손실 함수(loss): 0.345510
# 반복(Epoch): 3500, 트레이닝 데이터 정확도: 0.914062, 손실 함수(loss): 0.272480
# 반복(Epoch): 3600, 트레이닝 데이터 정확도: 0.882812, 손실 함수(loss): 0.261829
# 반복(Epoch): 3700, 트레이닝 데이터 정확도: 0.906250, 손실 함수(loss): 0.315324
# 반복(Epoch): 3800, 트레이닝 데이터 정확도: 0.929688, 손실 함수(loss): 0.246587
# 반복(Epoch): 3900, 트레이닝 데이터 정확도: 0.906250, 손실 함수(loss): 0.299488
# 반복(Epoch): 4000, 트레이닝 데이터 정확도: 0.914062, 손실 함수(loss): 0.282006
# 반복(Epoch): 4100, 트레이닝 데이터 정확도: 0.929688, 손실 함수(loss): 0.279480
# 반복(Epoch): 4200, 트레이닝 데이터 정확도: 0.945312, 손실 함수(loss): 0.140762
# 반복(Epoch): 4300, 트레이닝 데이터 정확도: 0.937500, 손실 함수(loss): 0.185146
# 반복(Epoch): 4400, 트레이닝 데이터 정확도: 0.937500, 손실 함수(loss): 0.146086
# 반복(Epoch): 4500, 트레이닝 데이터 정확도: 0.953125, 손실 함수(loss): 0.134319
# 반복(Epoch): 4600, 트레이닝 데이터 정확도: 0.945312, 손실 함수(loss): 0.151850
# 반복(Epoch): 4700, 트레이닝 데이터 정확도: 0.921875, 손실 함수(loss): 0.178854
# 반복(Epoch): 4800, 트레이닝 데이터 정확도: 0.968750, 손실 함수(loss): 0.094522
# 반복(Epoch): 4900, 트레이닝 데이터 정확도: 0.929688, 손실 함수(loss): 0.137198
# 반복(Epoch): 5000, 트레이닝 데이터 정확도: 0.937500, 손실 함수(loss): 0.159420
# 반복(Epoch): 5100, 트레이닝 데이터 정확도: 0.929688, 손실 함수(loss): 0.237604
# 반복(Epoch): 5200, 트레이닝 데이터 정확도: 0.984375, 손실 함수(loss): 0.084840
# 반복(Epoch): 5300, 트레이닝 데이터 정확도: 0.953125, 손실 함수(loss): 0.101080
# 반복(Epoch): 5400, 트레이닝 데이터 정확도: 0.890625, 손실 함수(loss): 0.337499
# 반복(Epoch): 5500, 트레이닝 데이터 정확도: 0.937500, 손실 함수(loss): 0.186651
# 반복(Epoch): 5600, 트레이닝 데이터 정확도: 0.921875, 손실 함수(loss): 0.194287
# 반복(Epoch): 5700, 트레이닝 데이터 정확도: 0.953125, 손실 함수(loss): 0.204942
# 반복(Epoch): 5800, 트레이닝 데이터 정확도: 0.976562, 손실 함수(loss): 0.088900
# 반복(Epoch): 5900, 트레이닝 데이터 정확도: 0.945312, 손실 함수(loss): 0.159079
# 반복(Epoch): 6000, 트레이닝 데이터 정확도: 0.960938, 손실 함수(loss): 0.116299
# 반복(Epoch): 6100, 트레이닝 데이터 정확도: 0.976562, 손실 함수(loss): 0.091587
# 반복(Epoch): 6200, 트레이닝 데이터 정확도: 0.984375, 손실 함수(loss): 0.068086
# 반복(Epoch): 6300, 트레이닝 데이터 정확도: 0.976562, 손실 함수(loss): 0.084112
# 반복(Epoch): 6400, 트레이닝 데이터 정확도: 0.992188, 손실 함수(loss): 0.020531
# 반복(Epoch): 6500, 트레이닝 데이터 정확도: 0.984375, 손실 함수(loss): 0.026090
# 반복(Epoch): 6600, 트레이닝 데이터 정확도: 0.984375, 손실 함수(loss): 0.057306
# 반복(Epoch): 6700, 트레이닝 데이터 정확도: 0.976562, 손실 함수(loss): 0.048627
# 반복(Epoch): 6800, 트레이닝 데이터 정확도: 0.953125, 손실 함수(loss): 0.155091
# 반복(Epoch): 6900, 트레이닝 데이터 정확도: 0.968750, 손실 함수(loss): 0.105226
# 반복(Epoch): 7000, 트레이닝 데이터 정확도: 0.960938, 손실 함수(loss): 0.199771
# 반복(Epoch): 7100, 트레이닝 데이터 정확도: 0.960938, 손실 함수(loss): 0.083110
# 반복(Epoch): 7200, 트레이닝 데이터 정확도: 0.992188, 손실 함수(loss): 0.033742
# 반복(Epoch): 7300, 트레이닝 데이터 정확도: 0.992188, 손실 함수(loss): 0.019168
# 반복(Epoch): 7400, 트레이닝 데이터 정확도: 0.976562, 손실 함수(loss): 0.072951
# 반복(Epoch): 7500, 트레이닝 데이터 정확도: 0.992188, 손실 함수(loss): 0.049593
# 반복(Epoch): 7600, 트레이닝 데이터 정확도: 0.968750, 손실 함수(loss): 0.113754
# 반복(Epoch): 7700, 트레이닝 데이터 정확도: 0.953125, 손실 함수(loss): 0.225817
# 반복(Epoch): 7800, 트레이닝 데이터 정확도: 0.992188, 손실 함수(loss): 0.017369
# 반복(Epoch): 7900, 트레이닝 데이터 정확도: 0.968750, 손실 함수(loss): 0.151341
# 반복(Epoch): 8000, 트레이닝 데이터 정확도: 0.976562, 손실 함수(loss): 0.054882
# 반복(Epoch): 8100, 트레이닝 데이터 정확도: 0.968750, 손실 함수(loss): 0.074013
# 반복(Epoch): 8200, 트레이닝 데이터 정확도: 0.960938, 손실 함수(loss): 0.163425
# 반복(Epoch): 8300, 트레이닝 데이터 정확도: 0.960938, 손실 함수(loss): 0.082315
# 반복(Epoch): 8400, 트레이닝 데이터 정확도: 0.984375, 손실 함수(loss): 0.119413
# 반복(Epoch): 8500, 트레이닝 데이터 정확도: 0.976562, 손실 함수(loss): 0.076829
# 반복(Epoch): 8600, 트레이닝 데이터 정확도: 0.976562, 손실 함수(loss): 0.058862
# 반복(Epoch): 8700, 트레이닝 데이터 정확도: 0.984375, 손실 함수(loss): 0.048336
# 반복(Epoch): 8800, 트레이닝 데이터 정확도: 0.960938, 손실 함수(loss): 0.150330
# 반복(Epoch): 8900, 트레이닝 데이터 정확도: 0.945312, 손실 함수(loss): 0.202198
# 반복(Epoch): 9000, 트레이닝 데이터 정확도: 0.992188, 손실 함수(loss): 0.023085
# 반복(Epoch): 9100, 트레이닝 데이터 정확도: 0.960938, 손실 함수(loss): 0.099781
# 반복(Epoch): 9200, 트레이닝 데이터 정확도: 0.992188, 손실 함수(loss): 0.054953
# 반복(Epoch): 9300, 트레이닝 데이터 정확도: 0.960938, 손실 함수(loss): 0.100952
# 반복(Epoch): 9400, 트레이닝 데이터 정확도: 0.968750, 손실 함수(loss): 0.197632
# 반복(Epoch): 9500, 트레이닝 데이터 정확도: 0.914062, 손실 함수(loss): 0.278627
# 반복(Epoch): 9600, 트레이닝 데이터 정확도: 0.945312, 손실 함수(loss): 0.101412
# 반복(Epoch): 9700, 트레이닝 데이터 정확도: 0.968750, 손실 함수(loss): 0.071174
# 반복(Epoch): 9800, 트레이닝 데이터 정확도: 0.976562, 손실 함수(loss): 0.054440
# 반복(Epoch): 9900, 트레이닝 데이터 정확도: 0.968750, 손실 함수(loss): 0.095045

# %%
test_accuracy = 0.0
for i in range(10):
  test_batch_x, test_batch_y = next(test_data_iter)
  test_accuracy = test_accuracy + compute_accuracy(CNN_model(test_batch_x, False)[0], test_batch_y).numpy()
test_accuracy = test_accuracy / 10
print("테스트 데이터 정확도: %f" % test_accuracy)
# Out:
# 테스트 데이터 정확도: 0.745700
