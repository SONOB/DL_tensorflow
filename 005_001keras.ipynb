# %%
import tensorflow as tf

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train, x_test = x_train.astype('float32'), x_test.astype('float32')

x_train, x_test = x_train.reshape([-1, 784]), x_test.reshape([-1, 784])

x_train, x_test = x_train/255., x_test/255.

y_train, y_test = tf.one_hot(y_train, depth=10), tf.one_hot(y_test, depth=10)

# %%
train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_data = train_data.repeat().shuffle(60000).batch(50)
train_data_iter = iter(train_data)

# %%
class CNN(tf.keras.Model):
  def __init__(self):
    super(CNN, self).__init__()

    self.conv_layer_1 = tf.keras.layers.Conv2D(filters=32, kernel_size=5, strides=1, padding='same', activation='relu')
    self.pool_layer_1 = tf.keras.layers.MaxPool2D(pool_size=(2,2), strides=2)

    self.conv_layer_2 = tf.keras.layers.Conv2D(filters=64, kernel_size=5, strides=1, padding='same', activation='relu')
    self.pool_layer_2 = tf.keras.layers.MaxPool2D(pool_size=(2, 2), strides=2)

    self.flatten_layer = tf.keras.layers.Flatten()
    self.fc_layer_1 = tf.keras.layers.Dense(1024, activation='relu')

    self.output_layer = tf.keras.layers.Dense(10, activation=None)

  def call(self, x):

    x_image = tf.reshape(x, [-1, 28, 28, 1])
    h_conv1 = self.conv_layer_1(x_image)
    h_pool1 = self.pool_layer_1(h_conv1)

    h_conv2 = self.conv_layer_2(h_pool1)
    h_pool2 = self.pool_layer_2(h_conv2)

    h_pool2_flat = self.flatten_layer(h_pool2)
    h_fc1 = self.fc_layer_1(h_pool2_flat)

    logits = self.output_layer(h_fc1)
    y_pred = tf.nn.softmax(logits)

    return y_pred, logits

# %%
@tf.function
def cross_entropy_loss(logits, y):
  return tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))

optimizer = tf.optimizers.Adam(1e-4)

# %%
@tf.function
def train_step(model, x, y):
  with tf.GradientTape()as tape:
    y_pred, logits = model(x)
    loss = cross_entropy_loss(logits, y)
  gradients = tape.gradient(loss, model.trainable_variables)
  optimizer.apply_gradients(zip(gradients, model.trainable_variables))

# %%
@tf.function
def compute_accuracy(y_pred, y):
  correct_prediction = tf.equal(tf.argmax(y_pred,1), tf.argmax(y,1))
  accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

  return accuracy

# %%
CNN_model = CNN()

# %%
for i in range(10000):
  batch_x, batch_y = next(train_data_iter)

  if i %100 == 0:
    train_accuracy = compute_accuracy(CNN_model(batch_x)[0], batch_y)
    print("반복(Epoch): %d, 트레이닝 데이터 정확도: %f" %(i, train_accuracy))
  train_step(CNN_model, batch_x, batch_y)
# Out:
# 반복(Epoch): 0, 트레이닝 데이터 정확도: 0.100000
# 반복(Epoch): 100, 트레이닝 데이터 정확도: 0.840000
# 반복(Epoch): 200, 트레이닝 데이터 정확도: 0.900000
# 반복(Epoch): 300, 트레이닝 데이터 정확도: 0.860000
# 반복(Epoch): 400, 트레이닝 데이터 정확도: 0.980000
# 반복(Epoch): 500, 트레이닝 데이터 정확도: 0.940000
# 반복(Epoch): 600, 트레이닝 데이터 정확도: 0.960000
# 반복(Epoch): 700, 트레이닝 데이터 정확도: 0.900000
# 반복(Epoch): 800, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 900, 트레이닝 데이터 정확도: 0.960000
# 반복(Epoch): 1000, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 1100, 트레이닝 데이터 정확도: 0.980000
# 반복(Epoch): 1200, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 1300, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 1400, 트레이닝 데이터 정확도: 0.960000
# 반복(Epoch): 1500, 트레이닝 데이터 정확도: 0.980000
# 반복(Epoch): 1600, 트레이닝 데이터 정확도: 0.940000
# 반복(Epoch): 1700, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 1800, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 1900, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 2000, 트레이닝 데이터 정확도: 0.940000
# 반복(Epoch): 2100, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 2200, 트레이닝 데이터 정확도: 0.980000
# 반복(Epoch): 2300, 트레이닝 데이터 정확도: 0.960000
# 반복(Epoch): 2400, 트레이닝 데이터 정확도: 0.960000
# 반복(Epoch): 2500, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 2600, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 2700, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 2800, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 2900, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 3000, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 3100, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 3200, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 3300, 트레이닝 데이터 정확도: 0.980000
# 반복(Epoch): 3400, 트레이닝 데이터 정확도: 0.940000
# 반복(Epoch): 3500, 트레이닝 데이터 정확도: 0.960000
# 반복(Epoch): 3600, 트레이닝 데이터 정확도: 0.960000
# 반복(Epoch): 3700, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 3800, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 3900, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 4000, 트레이닝 데이터 정확도: 0.960000
# 반복(Epoch): 4100, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 4200, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 4300, 트레이닝 데이터 정확도: 0.980000
# 반복(Epoch): 4400, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 4500, 트레이닝 데이터 정확도: 0.980000
# 반복(Epoch): 4600, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 4700, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 4800, 트레이닝 데이터 정확도: 0.980000
# 반복(Epoch): 4900, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 5000, 트레이닝 데이터 정확도: 0.960000
# 반복(Epoch): 5100, 트레이닝 데이터 정확도: 0.980000
# 반복(Epoch): 5200, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 5300, 트레이닝 데이터 정확도: 0.980000
# 반복(Epoch): 5400, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 5500, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 5600, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 5700, 트레이닝 데이터 정확도: 0.980000
# 반복(Epoch): 5800, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 5900, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 6000, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 6100, 트레이닝 데이터 정확도: 0.980000
# 반복(Epoch): 6200, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 6300, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 6400, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 6500, 트레이닝 데이터 정확도: 0.980000
# 반복(Epoch): 6600, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 6700, 트레이닝 데이터 정확도: 0.980000
# 반복(Epoch): 6800, 트레이닝 데이터 정확도: 0.980000
# 반복(Epoch): 6900, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 7000, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 7100, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 7200, 트레이닝 데이터 정확도: 0.980000
# 반복(Epoch): 7300, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 7400, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 7500, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 7600, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 7700, 트레이닝 데이터 정확도: 0.980000
# 반복(Epoch): 7800, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 7900, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 8000, 트레이닝 데이터 정확도: 0.980000
# 반복(Epoch): 8100, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 8200, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 8300, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 8400, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 8500, 트레이닝 데이터 정확도: 0.980000
# 반복(Epoch): 8600, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 8700, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 8800, 트레이닝 데이터 정확도: 0.980000
# 반복(Epoch): 8900, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 9000, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 9100, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 9200, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 9300, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 9400, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 9500, 트레이닝 데이터 정확도: 0.980000
# 반복(Epoch): 9600, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 9700, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 9800, 트레이닝 데이터 정확도: 1.000000
# 반복(Epoch): 9900, 트레이닝 데이터 정확도: 0.980000

# %%
print("정확도(Accuracy): %f" % compute_accuracy(CNN_model(x_test)[0], y_test))
# Out:
# 정확도(Accuracy): 0.991400
